# %%
import pandas as pd
# Load dataset
sales_data=pd.read_csv(r"C:\Users\spocy\Downloads\datasets-main\datasets-main\store_sales (1).csv")
sales_data.head()
# Out:
#   store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0      S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1      S_2  California   12   19   15   15   11   19     7   15   10   11
# 2      S_3  California   16   16   14   19   23    6    13   13   15   14
# 3      S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4      S_5       Texas   19    5   24    9    5   24    10    5   24   15
#
#    Nov  Dec
# 0    7    6
# 1   21   19
# 2   24    8
# 3    7   11
# 4    6   13

# %%
sales_data.tail()
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec
# 95   23   22
# 96   12    9
# 97   17   22
# 98   19   10
# 99    5    9

# %%
# Display shape
sales_data.shape
# Out:
# (100, 14)

# %%
# Display data types and non-null counts
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   store_id  100 non-null    object
#  1   city      100 non-null    object
#  2   Jan       100 non-null    int64
#  3   Feb       100 non-null    int64
#  4   Mar       100 non-null    int64
#  5   Apr       100 non-null    int64
#  6   May       100 non-null    int64
#  7   Jun       100 non-null    int64
#  8   July      100 non-null    int64
#  9   Aug       100 non-null    int64
#  10  Sep       100 non-null    int64
#  11  Oct       100 non-null    int64
#  12  Nov       100 non-null    int64
#  13  Dec       100 non-null    int64
# dtypes: int64(12), object(2)
# memory usage: 11.1+ KB

# %%
sales_data.columns
# Out:
# Index(['store_id', 'city', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'July',
#        'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
sales_data.describe
# Out:
# <bound method NDFrame.describe of    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# ..      ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec
# 0     7    6
# ...

# %%
# Calculate total and average sales per month
monthly_sales=sales_data[['Jan','Feb','Mar','Apr']]
# Total sales per month
total_sales = monthly_sales.sum()
print(total_sales)
# Out:
# Jan    1446
# Feb    1509
# Mar    1456
# Apr    1457
# dtype: int64

# %%
# Average sales per month
average_sales = monthly_sales.mean()
print( average_sales)
# Out:
# Jan    14.46
# Feb    15.09
# Mar    14.56
# Apr    14.57
# dtype: float64

# %%
# Total yearly sales for all stores combined
total_yearly_sales_all_stores = sales_data[['Jan','Feb','Mar','Apr']].sum()
print(total_yearly_sales_all_stores)
# Out:
# Jan    1446
# Feb    1509
# Mar    1456
# Apr    1457
# dtype: int64

# %%
# Add Total_Sales column (sum of Jan to Apr)
sales_data['TOTAL_SALES']=sales_data[['Jan','Feb','Mar','Apr']].sum(axis=1)
sales_data.head()
# Out:
#   store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0      S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1      S_2  California   12   19   15   15   11   19     7   15   10   11
# 2      S_3  California   16   16   14   19   23    6    13   13   15   14
# 3      S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4      S_5       Texas   19    5   24    9    5   24    10    5   24   15
#
#    Nov  Dec  TOTAL_SALES
# 0    7    6           62
# 1   21   19           61
# 2   24    8           65
# 3    7   11           49
# 4    6   13           57

# %%
# Top 5 stores with highest Total_Sales
top_5= sales_data.sort_values(by='TOTAL_SALES',ascending=False).head(5)
top_5[['store_id','TOTAL_SALES']]
# Out:
#    store_id  TOTAL_SALES
# 72     S_73           86
# 77     S_78           85
# 69     S_70           84
# 26     S_27           80
# 85     S_86           80

# %%
# Bottom 5 stores with lowest Total_Sales
bottom_5=sales_data.sort_values(by='TOTAL_SALES',ascending=True).head(5)
bottom_5[['store_id','TOTAL_SALES']]
# Out:
#    store_id  TOTAL_SALES
# 90     S_91           33
# 18     S_19           38
# 82     S_83           39
# 21     S_22           39
# 96     S_97           41

# %%
# Find store with maximum sales in March
max_march=sales_data.loc[sales_data['Mar'].idxmax(), 'store_id']
max_march
# Out:
# 'S_5'

# %%
# Find store with maximum sales in April
min_apr=sales_data.loc[sales_data['Apr'].idxmin(), 'store_id']
min_apr
# Out:
# 'S_32'

# %%
# Filter stores from California that had sales > 20 in any month.
sales_data[(sales_data['city']=='California')&((sales_data['Jan']>20)|(sales_data['Feb']>20)|(sales_data['Mar']>20)|(sales_data['Apr']>20))][['store_id','Jan','Feb','Mar','Apr','TOTAL_SALES']]
# Out:
#    store_id  Jan  Feb  Mar  Apr  TOTAL_SALES
# 5       S_6   14   21   18   20           73
# 9      S_10   14   23   20   11           68
# 11     S_12    6   18   21    8           53
# 16     S_17   13    8    7   22           50
# 19     S_20   11   21   20    6           58
# 25     S_26   24   11   16   11           62
# 26     S_27   24   19   13   24           80
# 27     S_28   10   15   24   21           70
# 34     S_35   10    7   24   15           56
# 36     S_37   24   16    9    6           55
# 37     S_38   21   10   13   11           55
# 48     S_49   22   22   10   11           65
# 59     S_60    6   21   22    8           57
# 61     S_62   16   21    6   22           65
# 67     S_68   23   15   16   14           68
# 72     S_73   20   24   24   18           86
# 80     S_81   22    9   20   12           63
# 85     S_86   15   23   24   18           80
# 89     S_90    8   23   21   14           66
# 93     S_94   19   18   14   21           72
# ...

# %%
# Calculate average sales per store across all months (Jan–Apr)
sales_data['AVERAGE_SALES']=(sales_data['Jan']+sales_data['Feb']+sales_data['Mar']+sales_data['Apr']) / 4
sales_data.head()
# Out:
#   store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0      S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1      S_2  California   12   19   15   15   11   19     7   15   10   11
# 2      S_3  California   16   16   14   19   23    6    13   13   15   14
# 3      S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4      S_5       Texas   19    5   24    9    5   24    10    5   24   15
#
#    Nov  Dec  TOTAL_SALES  AVERAGE_SALES
# 0    7    6           62          15.50
# 1   21   19           61          15.25
# 2   24    8           65          16.25
# 3    7   11           49          12.25
# 4    6   13           57          14.25

# %%
# Sort stores by average sales in descending order
sales_data_sorted = sales_data.sort_values(by='AVERAGE_SALES', ascending=False)
sales_data_sorted[['store_id','Jan','Feb','Mar','Apr','AVERAGE_SALES']]
# Out:
#    store_id  Jan  Feb  Mar  Apr  AVERAGE_SALES
# 72     S_73   20   24   24   18          21.50
# 77     S_78   19   23   19   24          21.25
# 69     S_70   24   16   24   20          21.00
# 26     S_27   24   19   13   24          20.00
# 85     S_86   15   23   24   18          20.00
# ..      ...  ...  ...  ...  ...            ...
# 96     S_97   13    6    7   15          10.25
# 82     S_83   16    5    6   12           9.75
# 21     S_22   12    8    6   13           9.75
# 18     S_19    7    6   17    8           9.50
# 90     S_91   14    5    5    9           8.25
#
# [100 rows x 6 columns]

# %%
# Calculate total sales for each month
total_per_month=sales_data[['Jan','Feb','Mar','Apr']].sum()
# Find the month with highest total sales
month_highest=total_per_month.idxmax()
month_highest
# Out:
# 'Feb'

# %%
# For each store, find the month with maximum sales
sales_data['MONTH_MAX'] = sales_data[['Jan','Feb','Mar','Apr']].idxmax(axis=1)
sales_data[['store_id','Jan','Feb','Mar','Apr','MONTH_MAX']]
# Out:
#    store_id  Jan  Feb  Mar  Apr MONTH_MAX
# 0       S_1    8   20   13   21       Apr
# 1       S_2   12   19   15   15       Feb
# 2       S_3   16   16   14   19       Apr
# 3       S_4    8   18   13   10       Feb
# 4       S_5   19    5   24    9       Mar
# ..      ...  ...  ...  ...  ...       ...
# 95     S_96    7   10   20   20       Mar
# 96     S_97   13    6    7   15       Apr
# 97     S_98   16    9    6   14       Jan
# 98     S_99   18   16    9    5       Jan
# 99    S_100    5   23   17   24       Apr
#
# [100 rows x 6 columns]

# %%
# Store with maximum sales in March
max_march=sales_data.loc[sales_data['Mar'].idxmax(),'store_id']
max_march
# Out:
# 'S_5'
